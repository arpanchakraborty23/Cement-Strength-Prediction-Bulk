# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0               1040.0            676.0   28                          79.99
# 1               1055.0            676.0   28                          61.89
# 2                932.0            594.0  270                          40.27
# 3                932.0            594.0  365                          41.05
# 4                978.4            825.5  360                          44.30
# ...                ...              ...  ...                            ...
# 1025             870.1            768.3   28                          44.28
# 1026             817.9            813.4   28                          31.18
# 1027             892.4            780.0   28                          23.70
# 1028             989.6            788.9   28                          32.77
# 1029             864.5            761.5   28                          32.40
#
# [1030 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         1030 non-null   float64
#  1   blast_furnace_slag             1030 non-null   float64
#  2   fly_ash                        1030 non-null   float64
#  3   water                          1030 non-null   float64
#  4   superplasticizer               1030 non-null   float64
#  5   coarse_aggregate               1030 non-null   float64
#  6   fine_aggregate                 1030 non-null   float64
#  7   age                            1030 non-null   int64
#  8   concrete_compressive_strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe()
# Out:
#             cement  blast_furnace_slag      fly_ash        water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        superplasticizer  coarse_aggregate  fine_aggregate           age  \
# count       1030.000000       1030.000000      1030.000000  1030.000000
# mean           6.204660        972.918932       773.580485    45.662136
# std            5.973841         77.753954        80.175980    63.169912
# min            0.000000        801.000000       594.000000     1.000000
# 25%            0.000000        932.000000       730.950000     7.000000
# 50%            6.400000        968.000000       779.500000    28.000000
# 75%           10.200000       1029.400000       824.000000    56.000000
# max           32.200000       1145.000000       992.600000   365.000000
#
#        concrete_compressive_strength
# count                    1030.000000
# mean                       35.817961
# std                        16.705742
# min                         2.330000
# 25%                        23.710000
# 50%                        34.445000
# 75%                        46.135000
# max                        82.600000

# %%
df.isnull().sum()
# Out:
# cement                           0
# blast_furnace_slag               0
# fly_ash                          0
# water                            0
# superplasticizer                 0
# coarse_aggregate                 0
# fine_aggregate                   0
# age                              0
# concrete_compressive_strength    0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15,8))
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(15, 60))

for i, col in enumerate(df.columns):
    plt.subplot(10, 2, i+1)
    sns.distplot(x=df[col], color='indianred')
    plt.xlabel(col, weight='bold')
    plt.tight_layout()
# Out:
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')
# C:\Users\www58\AppData\Local\Temp\ipykernel_28500\2690368516.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[col], color='indianred')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %% [markdown]
# ## Data Transformation

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# File E:\cement\cm\lib\site-packages\sklearn\__init__.py:87
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      81     # later is linked to the OpenMP runtime to make it possible to introspect
#      82     # it and importing it first would fail if the OpenMP dll cannot be found.
#      83     from . import (
#      84         __check_build,  # noqa: F401
#      85         _distributor_init,  # noqa: F401
#      86     )
# ---> 87     from .base import clone
#      88     from .utils._show_versions import show_versions
#      90     __all__ = [
#      91         "calibration",
#      92         "cluster",
#    (...)
#     133         "show_versions",
#     134     ]
#
# File E:\cement\cm\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#
# File E:\cement\cm\lib\site-packages\sklearn\utils\__init__.py:22
#      20 from . import _joblib, metadata_routing
#      21 from ._bunch import Bunch
# ---> 22 from ._estimator_html_repr import estimator_html_repr
#      23 from ._param_validation import Integral, Interval, validate_params
#      24 from .class_weight import compute_class_weight, compute_sample_weight
#
# File E:\cement\cm\lib\site-packages\sklearn\utils\_estimator_html_repr.py:10
#       7 from string import Template
#       9 from .. import __version__, config_context
# ---> 10 from .fixes import parse_version
#      13 class _IDCounter:
#      14     """Generate sequential ids with a prefix."""
#
# File E:\cement\cm\lib\site-packages\sklearn\utils\fixes.py:17
#      15 import scipy
#      16 import scipy.sparse.linalg
# ---> 17 import scipy.stats
#      18 import threadpoolctl
#      20 import sklearn
#
# File E:\cement\cm\lib\site-packages\scipy\stats\__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File E:\cement\cm\lib\site-packages\scipy\stats\_stats_py.py:49
#      47 import scipy.special as special
#      48 from scipy import linalg
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      51 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      52                                    siegelslopes)
#
# File E:\cement\cm\lib\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File E:\cement\cm\lib\site-packages\scipy\stats\_continuous_distns.py:33
#      30 from ._constants import (_XMIN, _LOGXMIN, _EULER, _ZETA3, _SQRT_PI,
#      31                          _SQRT_2_OVER_PI, _LOG_SQRT_2_OVER_PI)
#      32 from ._censored_data import CensoredData
# ---> 33 import scipy.stats._boost as _boost
#      34 from scipy.optimize import root_scalar
#      35 from scipy.stats._warnings_errors import FitError
#
# File E:\cement\cm\lib\site-packages\scipy\stats\_boost\__init__.py:37
#      25 from scipy.stats._boost.ncf_ufunc import (
#      26     _ncf_pdf, _ncf_cdf, _ncf_sf, _ncf_ppf,
#      27     _ncf_isf, _ncf_mean, _ncf_variance,
#      28     _ncf_skewness, _ncf_kurtosis_excess,
#      29 )
#      31 from scipy.stats._boost.ncx2_ufunc import (
#      32     _ncx2_pdf, _ncx2_cdf, _ncx2_sf, _ncx2_ppf,
#      33     _ncx2_isf, _ncx2_mean, _ncx2_variance,
#      34     _ncx2_skewness, _ncx2_kurtosis_excess,
#      35 )
# ---> 37 from scipy.stats._boost.nct_ufunc import (
#      38     _nct_pdf, _nct_cdf, _nct_sf, _nct_ppf,
#      39     _nct_isf, _nct_mean, _nct_variance,
#      40     _nct_skewness, _nct_kurtosis_excess,
#      41 )
#      43 from scipy.stats._boost.skewnorm_ufunc import (
#      44     _skewnorm_pdf, _skewnorm_cdf, _skewnorm_sf, _skewnorm_ppf,
#      45     _skewnorm_isf, _skewnorm_mean, _skewnorm_variance,
#      46     _skewnorm_skewness, _skewnorm_kurtosis_excess,
#      47 )
#      49 from scipy.stats._boost.invgauss_ufunc import (
#      50     _invgauss_pdf, _invgauss_cdf, _invgauss_sf, _invgauss_ppf,
#      51     _invgauss_isf, _invgauss_mean, _invgauss_variance,
#      52     _invgauss_skewness, _invgauss_kurtosis_excess,
#      53 )
#
# ModuleNotFoundError: No module named 'scipy.stats._boost.nct_ufunc'

# %%
x=df.drop('	concrete_compressive_strength',axis=1)
y=df['concrete_compressive_strength']
